# %% [markdown]
# ## Check Data Input

# %%
import pandas as pd

# %% [markdown]
# #### Google Reviews

# %%
google_df = pd.read_csv("../data_input/google_reviews.csv")

print(google_df.shape)
display(google_df.head(n=2))
# Out:
# (1100, 6)
#                      business_name    author_name  \
# 0  Haci'nin Yeri - Yigit Lokantasi    Gulsum Akar
# 1  Haci'nin Yeri - Yigit Lokantasi  Oguzhan Cetin
#
#                                                 text  \
# 0  We went to Marmaris with my wife for a holiday...
# 1  During my holiday in Marmaris we ate here to f...
#
#                                          photo  rating rating_category
# 0   dataset/taste/hacinin_yeri_gulsum_akar.png       5           taste
# 1  dataset/menu/hacinin_yeri_oguzhan_cetin.png       4            menu

# %% [markdown]
# #### Amazon Reviews

# %%
amazon_df = pd.read_csv("../data_input/amazon_reviews.csv", 
            names=['rating', 'reviewing_heading', 'review_text'])

print(amazon_df.shape)
display(amazon_df.head(n=2))
# Out:
# (400000, 3)
#    rating                                  reviewing_heading  \
# 0       2                                           Great CD
# 1       2  One of the best game music soundtracks - for a...
#
#                                          review_text
# 0  My lovely Pat has one of the GREAT voices of h...
# 1  Despite the fact that I have only played a sma...
