# %% [markdown]
# ## Check Data Input

# %%
import pandas as pd

# %% [markdown]
# #### Google Reviews

# %%
google_df = pd.read_csv("../data_input/google_reviews.csv")

print(google_df.shape)
display(google_df.head(n=2))
# Out:
# (1100, 6)
#                      business_name    author_name  \
# 0  Haci'nin Yeri - Yigit Lokantasi    Gulsum Akar
# 1  Haci'nin Yeri - Yigit Lokantasi  Oguzhan Cetin
#
#                                                 text  \
# 0  We went to Marmaris with my wife for a holiday...
# 1  During my holiday in Marmaris we ate here to f...
#
#                                          photo  rating rating_category
# 0   dataset/taste/hacinin_yeri_gulsum_akar.png       5           taste
# 1  dataset/menu/hacinin_yeri_oguzhan_cetin.png       4            menu

# %%
print(google_df['business_name'].nunique())
print(google_df['author_name'].nunique())
print(google_df['rating_category'].value_counts())
# Out:
# 100
# 1074
# rating_category
# taste                 330
# indoor_atmosphere     288
# outdoor_atmosphere    286
# menu                  196
# Name: count, dtype: int64

# %%
exp_df = google_df[google_df['business_name'] == "Haci'nin Yeri - Yigit Lokantasi"]
print(exp_df.shape)
display(exp_df)
# Out:
# (11, 6)
#                       business_name    author_name  \
# 0   Haci'nin Yeri - Yigit Lokantasi    Gulsum Akar
# 1   Haci'nin Yeri - Yigit Lokantasi  Oguzhan Cetin
# 2   Haci'nin Yeri - Yigit Lokantasi     Yasin Kuyu
# 3   Haci'nin Yeri - Yigit Lokantasi     Orhan Kapu
# 4   Haci'nin Yeri - Yigit Lokantasi     Ozgur Sati
# 5   Haci'nin Yeri - Yigit Lokantasi    Arda Karaca
# 6   Haci'nin Yeri - Yigit Lokantasi      İrem Eren
# 7   Haci'nin Yeri - Yigit Lokantasi    Nadia Salim
# 8   Haci'nin Yeri - Yigit Lokantasi    Mehmet Eser
# 9   Haci'nin Yeri - Yigit Lokantasi     Celal Ozer
# 10  Haci'nin Yeri - Yigit Lokantasi    Onur Celebi
#
#                                                  text  \
# 0   We went to Marmaris with my wife for a holiday...
# 1   During my holiday in Marmaris we ate here to f...
# 2   Prices are very affordable. The menu in the ph...
# 3   Turkey's cheapest artisan restaurant and its f...
# 4   I don't know what you will look for in terms o...
# ...

# %% [markdown]
# #### Amazon Reviews

# %%
amazon_df = pd.read_csv("../data_input/amazon_reviews.csv", 
            names=['rating', 'reviewing_heading', 'review_text'])

print(amazon_df.shape)
display(amazon_df.head(n=2))
# Out:
# (400000, 3)
#    rating                                  reviewing_heading  \
# 0       2                                           Great CD
# 1       2  One of the best game music soundtracks - for a...
#
#                                          review_text
# 0  My lovely Pat has one of the GREAT voices of h...
# 1  Despite the fact that I have only played a sma...
